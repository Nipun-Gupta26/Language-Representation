# %%
import pickle
import pandas as pd

# %%
word_pairs = [
    ("happy", "खुश"), ("sad", "दुखी"), ("strong", "मजबूत"), ("weak", "कमज़ोर"), 
    ("fast", "तेज़"), ("slow", "धीमा"), ("bright", "चमकीला"), ("dark", "अंधेरा"), 
    ("hot", "गर्म"), ("cold", "ठंडा"), ("big", "बड़ा"), ("small", "छोटा"), 
    ("new", "नया"), ("old", "पुराना"), ("hard", "कठिन"), ("soft", "नरम"), 
    ("early", "जल्दी"), ("late", "देर"), ("clean", "साफ"), ("dirty", "गंदा"),
    ("easy", "आसान"), ("difficult", "मुश्किल"), ("deep", "गहरा"), ("shallow", "उथला"),
    ("open", "खुला"), ("closed", "बंद"), ("right", "सही"), ("wrong", "गलत"),
    ("left", "बायां"), ("right", "दायां"), ("near", "नज़दीक"), ("far", "दूर"),
    ("cheap", "सस्ता"), ("expensive", "महंगा"), ("light", "हल्का"), ("heavy", "भारी"),
    ("good", "अच्छा"), ("bad", "बुरा"), ("beautiful", "सुंदर"), ("ugly", "कुरूप"),
    ("angry", "गुस्सैल"), ("healthy", "स्वस्थ"), ("sick", "बीमार"), ("friendly", "मित्रवत"), 
    ("unfriendly", "अमित्र"), ("safe", "सुरक्षित"), ("dangerous", "खतरनाक"), ("kind", "दयालु"), 
    ("cruel", "निर्दयी"), ("honest", "ईमानदार"), ("dishonest", "बेईमान"), ("rich", "अमीर"), 
    ("poor", "गरीब"), ("thin", "पतला"), ("fat", "मोटा"), ("warm", "गर्म"), ("cool", "ठंडा"), 
    ("sharp", "तेज"), ("dull", "मंद"), ("clear", "स्पष्ट"), ("confused", "उलझा हुआ"), 
    ("useful", "उपयोगी"), ("useless", "व्यर्थ"), ("true", "सत्य"), ("false", "असत्य"), 
    ("full", "भरा"), ("empty", "खाली"), ("intelligent", "बुद्धिमान"), ("stupid", "मूर्ख"),
    ("interesting", "दिलचस्प"), ("boring", "उबाऊ"), ("generous", "उदार"), ("selfish", "स्वार्थी"),
    ("brave", "बहादुर"), ("cowardly", "कायर"), ("polite", "विनम्र"), ("rude", "अशिष्ट"),
    ("modern", "आधुनिक"), ("traditional", "पारंपरिक"), ("tight", "कसा हुआ"), ("loose", "ढीला"),
    ("private", "निजी"), ("public", "सार्वजनिक"), ("busy", "व्यस्त"), ("free", "मुक्त"),
    ("simple", "सरल"), ("complicated", "जटिल"), ("silent", "चुप"), ("noisy", "शोरगुल वाला"),
    ("famous", "प्रसिद्ध"), ("unknown", "अज्ञात"), ("reliable", "विश्वसनीय"), ("unreliable", "अविश्वसनीय"),
    ("short", "छोटा"), ("long", "लंबा"), ("important", "महत्वपूर्ण"), ("unimportant", "अहमियतहीन"),
    ("correct", "सही"), ("incorrect", "गलत"), ("visible", "दृश्यमान"), ("invisible", "अदृश्य"),
    ("logical", "तार्किक"), ("illogical", "अतार्किक"), ("frequent", "बार-बार"), ("rare", "दुर्लभ"),
    ("happy", "खुश"), ("sad", "दुखी"), ("strong", "मजबूत"), ("weak", "कमज़ोर"), 
    ("fast", "तेज़"), ("slow", "धीमा"), ("bright", "चमकीला"), ("dark", "अंधेरा"), 
    ("hot", "गर्म"), ("cold", "ठंडा"), ("big", "बड़ा"), ("small", "छोटा"), 
    ("new", "नया"), ("old", "पुराना"), ("hard", "कठिन"), ("soft", "नरम"), 
    ("early", "जल्दी"), ("late", "देर"), ("clean", "साफ"), ("dirty", "गंदा"),
    ("easy", "आसान"), ("difficult", "मुश्किल"), ("deep", "गहरा"), ("shallow", "उथला"),
    ("open", "खुला"), ("closed", "बंद"), ("right", "सही"), ("wrong", "गलत"),
    ("left", "बायां"), ("right", "दायां"), ("near", "नज़दीक"), ("far", "दूर"),
    ("cheap", "सस्ता"), ("expensive", "महंगा"), ("light", "हल्का"), ("heavy", "भारी"),
    ("good", "अच्छा"), ("bad", "बुरा"), ("beautiful", "सुंदर"), ("ugly", "कुरूप"),
    ("angry", "गुस्सैल"), ("healthy", "स्वस्थ"), ("sick", "बीमार"), ("friendly", "मित्रवत"), 
    ("unfriendly", "अमित्र"), ("safe", "सुरक्षित"), ("dangerous", "खतरनाक"), ("kind", "दयालु"), 
    ("cruel", "निर्दयी"), ("honest", "ईमानदार"), ("dishonest", "बेईमान"), ("rich", "अमीर"), 
    ("poor", "गरीब"), ("thin", "पतला"), ("fat", "मोटा"), ("warm", "गर्म"), ("cool", "ठंडा"), 
    ("sharp", "तेज"), ("dull", "मंद"), ("clear", "स्पष्ट"), ("confused", "उलझा हुआ"), 
    ("useful", "उपयोगी"), ("useless", "व्यर्थ"), ("true", "सत्य"), ("false", "असत्य"), 
    ("full", "भरा"), ("empty", "खाली"), ("intelligent", "बुद्धिमान"), ("stupid", "मूर्ख"),
    ("interesting", "दिलचस्प"), ("boring", "उबाऊ"), ("generous", "उदार"), ("selfish", "स्वार्थी"),
    ("brave", "बहादुर"), ("cowardly", "कायर"), ("polite", "विनम्र"), ("rude", "अशिष्ट"),
    ("modern", "आधुनिक"), ("traditional", "पारंपरिक"), ("tight", "कसा हुआ"), ("loose", "ढीला"),
    ("private", "निजी"), ("public", "सार्वजनिक"), ("busy", "व्यस्त"), ("free", "मुक्त"),
    ("simple", "सरल"), ("complicated", "जटिल"), ("silent", "चुप"), ("noisy", "शोरगुल वाला"),
    ("famous", "प्रसिद्ध"), ("unknown", "अज्ञात"), ("reliable", "विश्वसनीय"), ("unreliable", "अविश्वसनीय"),
    ("short", "छोटा"), ("long", "लंबा"), ("important", "महत्वपूर्ण"), ("unimportant", "अहमियतहीन"),
    ("correct", "सही"), ("incorrect", "गलत"), ("visible", "दृश्यमान"), ("invisible", "अदृश्य"),
    ("logical", "तार्किक"), ("illogical", "अतार्किक"), ("frequent", "बार-बार"), ("rare", "दुर्लभ"),
    ("honor", "सम्मान"), ("shame", "लज्जा"), ("victory", "विजय"), ("defeat", "पराजय"),
    ("trust", "विश्वास"), ("doubt", "संदेह"), ("happiness", "खुशी"), ("sorrow", "दुःख"),
    ("beginning", "शुरुआत"), ("end", "अंत"), ("success", "सफलता"), ("failure", "असफलता"),
    ("love", "प्रेम"), ("hate", "घृणा"), ("hope", "आशा"), ("despair", "निराशा"),
    ("day", "दिन"), ("night", "रात"), ("summer", "गर्मी"), ("winter", "सर्दी"),
    ("north", "उत्तर"), ("south", "दक्षिण"), ("east", "पूर्व"), ("west", "पश्चिम"),
    ("father", "पिता"), ("mother", "माता"), ("brother", "भाई"), ("sister", "बहन"),
    ("son", "बेटा"), ("daughter", "बेटी"), ("husband", "पति"), ("wife", "पत्नी"),
    ("teacher", "शिक्षक"), ("student", "छात्र"), ("doctor", "डॉक्टर"), ("engineer", "अभियंता"),
    ("lawyer", "वकील"), ("farmer", "किसान"), ("soldier", "सैनिक"), ("businessman", "व्यवसायी"),
    ("leader", "नेता"), ("follower", "अनुयायी"), ("buyer", "खरीददार"), ("seller", "विक्रेता"),
    ("creator", "निर्माता"), ("destroyer", "विनाशक"), ("worker", "मज़दूर"), ("boss", "मालिक"),
    ("mountain", "पहाड़"), ("river", "नदी"), ("ocean", "महासागर"), ("forest", "जंगल"),
    ("earth", "पृथ्वी"), ("sky", "आकाश"), ("sun", "सूर्य"), ("moon", "चंद्रमा"),
    ("star", "तारा"), ("cloud", "बादल"), ("rain", "बारिश"), ("storm", "तूफान"),
    ("lightning", "बिजली"), ("thunder", "गर्जन"), ("wind", "हवा"), ("breeze", "समीर"),
    ("fire", "आग"), ("water", "पानी"), ("air", "वायु"), ("soil", "मिट्टी"),
    ("gold", "सोना"), ("silver", "चांदी"), ("copper", "तांबा"), ("iron", "लोहा"),
    ("wood", "लकड़ी"), ("stone", "पत्थर"), ("sand", "रेत"), ("glass", "कांच"),
    ("book", "किताब"), ("pen", "कलम"), ("paper", "कागज"), ("notebook", "कॉपी"),
    ("window", "खिड़की"), ("door", "दरवाजा"), ("wall", "दीवार"), ("roof", "छत"),
    ("table", "मेज़"), ("chair", "कुर्सी"), ("bed", "बिस्तर"), ("pillow", "तकिया"),
    ("food", "भोजन"), ("water", "जल"), ("milk", "दूध"), ("honey", "शहद"),
    ("sugar", "चीनी"), ("salt", "नमक"), ("spice", "मसाला"), ("flour", "आटा"),
    ("rice", "चावल"), ("wheat", "गेहूं"), ("corn", "मक्का"), ("barley", "जौ"),
    ("teacher", "अध्यापक"), ("pupil", "विद्यार्थी"), ("lecture", "व्याख्यान"), ("lesson", "पाठ"),
    ("university", "विश्वविद्यालय"), ("school", "विद्यालय"), ("college", "महाविद्यालय"), ("exam", "परीक्षा"),
    ("question", "प्रश्न"), ("answer", "उत्तर"), ("notebook", "नोटबुक"), ("textbook", "पाठ्यपुस्तक"),
    ("subject", "विषय"), ("chapter", "अध्याय"), ("paragraph", "अनुच्छेद"), ("sentence", "वाक्य"),
    ("word", "शब्द"), ("alphabet", "वर्णमाला"), ("language", "भाषा"), ("translation", "अनुवाद"),
    ("dictionary", "शब्दकोश"), ("grammar", "व्याकरण"), ("literature", "साहित्य"), ("poetry", "कविता"),
    ("novel", "उपन्यास"), ("story", "कहानी"), ("journal", "पत्रिका"), ("newspaper", "समाचार पत्र"),
    ("editor", "संपादक"), ("author", "लेखक"), ("reader", "पाठक"), ("library", "पुस्तकालय"),
    ("bookstore", "पुस्तक भंडार"), ("pen", "पेन"), ("pencil", "पेंसिल"), ("eraser", "रबर"),
    ("ruler", "पट्टी"), ("sharpener", "चोखा करने वाला"), ("ink", "स्याही"), ("paper", "कागज"),
    ("document", "दस्तावेज"), ("certificate", "प्रमाण पत्र"), ("contract", "अनुबंध"), ("signature", "हस्ताक्षर"),
    ("account", "खाता"), ("balance", "शेष राशि"), ("credit", "ऋण"), ("debit", "जमा"),
    ("interest", "ब्याज"), ("loan", "ऋण"), ("deposit", "जमा"), ("withdrawal", "निकासी"),
    ("bank", "बैंक"), ("currency", "मुद्रा"), ("coin", "सिक्का"), ("note", "नोट"),
    ("payment", "भुगतान"), ("transaction", "लेनदेन"), ("exchange", "विनिमय"), ("trade", "व्यापार"),
    ("market", "बाजार"), ("shop", "दुकान"), ("seller", "विक्रेता"), ("buyer", "खरीददार"),
    ("customer", "ग्राहक"), ("order", "आदेश"), ("supply", "आपूर्ति"), ("demand", "मांग"),
    ("business", "व्यवसाय"), ("industry", "उद्योग"), ("company", "कंपनी"), ("enterprise", "उद्यम"),
    ("corporation", "संघ"), ("profit", "लाभ"), ("loss", "हानि"), ("investment", "निवेश"),
    ("salary", "वेतन"), ("wages", "मजदूरी"), ("employment", "रोजगार"), ("unemployment", "बेरोजगारी"),
    ("worker", "श्रमिक"), ("job", "नौकरी"), ("position", "पद"), ("promotion", "पदोन्नति"),
    ("resignation", "इस्तीफा"), ("retirement", "सेवानिवृत्ति"), ("pension", "पेंशन"), ("tax", "कर"),
    ("budget", "बजट"), ("expense", "व्यय"), ("saving", "बचत"), ("wealth", "धन"),
    ("poverty", "गरीबी"), ("rich", "धनी"), ("poor", "निर्धन"), ("charity", "दान"),
    ("donation", "अंशदान"), ("gift", "उपहार"), ("prize", "पुरस्कार"), ("reward", "इनाम"),
    ("teacher", "शिक्षक"), ("students", "छात्र"), ("lessons", "पाठ"), ("questions", "प्रश्न"),
    ("answers", "उत्तर"), ("notebooks", "कॉपी"), ("libraries", "पुस्तकालय"), ("universities", "विश्वविद्यालय"),
    ("banks", "बैंक"), ("companies", "कंपनियां"), ("industries", "उद्योग"), ("markets", "बाजार"),
    ("shops", "दुकानें"), ("traders", "व्यापारी"), ("employers", "नियोक्ता"), ("employees", "कर्मचारी"),
    ("profits", "लाभ"), ("losses", "हानि"), ("richness", "धन-सम्पदा"), ("poverty", "निर्धनता"),
    ("salary", "मासिक वेतन"), ("wages", "दैनिक मजदूरी"), ("job", "कार्य"), ("jobs", "नौकरियां"),
    ("career", "पेशा"), ("business", "कारोबार"), ("enterprise", "उद्यम"), ("commerce", "व्यापार"),
    ("purchase", "खरीद"), ("sales", "बिक्री"), ("exchange", "बदलाव"), ("investment", "पूंजी निवेश"),
    ("taxes", "कर"), ("budgeting", "बजट निर्माण"), ("savings", "बचत योजनाएं"), ("expenses", "खर्चे"),
    ("run", "दौड़ना"), ("walk", "चलना"), ("jump", "कूदना"), ("sit", "बैठना"), ("stand", "खड़ा होना"),
    ("sleep", "सोना"), ("wake", "जागना"), ("eat", "खाना"), ("drink", "पीना"), ("read", "पढ़ना"),
    ("write", "लिखना"), ("speak", "बोलना"), ("listen", "सुनना"), ("see", "देखना"), ("touch", "छूना"),
    ("think", "सोचना"), ("understand", "समझना"), ("remember", "याद करना"), ("forget", "भूलना"),
    ("help", "मदद करना"), ("teach", "सिखाना"), ("learn", "सीखना"), ("buy", "खरीदना"), ("sell", "बेचना"),
    ("open", "खोलना"), ("close", "बंद करना"), ("start", "शुरू करना"), ("stop", "रोकना"), ("love", "प्यार करना"),
    ("hate", "नफरत करना"), ("like", "पसंद करना"), ("dislike", "नापसंद करना"), ("win", "जीतना"),
    ("lose", "हारना"), ("give", "देना"), ("take", "लेना"), ("show", "दिखाना"), ("hide", "छिपाना"),
    ("break", "तोड़ना"), ("fix", "सुधारना"), ("create", "बनाना"), ("destroy", "नष्ट करना"),
    ("big", "बड़ा"), ("small", "छोटा"), ("fast", "तेज़"), ("slow", "धीमा"), ("strong", "मज़बूत"),
    ("weak", "कमज़ोर"), ("bright", "चमकदार"), ("dark", "अंधेरा"), ("hot", "गर्म"), ("cold", "ठंडा"),
    ("happy", "खुश"), ("sad", "उदास"), ("angry", "गुस्से में"), ("calm", "शांत"), ("brave", "बहादुर"),
    ("coward", "कायर"), ("rich", "अमीर"), ("poor", "गरीब"), ("beautiful", "सुंदर"), ("ugly", "बदसूरत"),
    ("new", "नया"), ("old", "पुराना"), ("young", "युवा"), ("old", "बूढ़ा"), ("empty", "खाली"),
    ("full", "भरा हुआ"), ("soft", "नरम"), ("hard", "कठिन"), ("wet", "गीला"), ("dry", "सूखा"),
    ("clean", "साफ"), ("dirty", "गंदा"), ("sharp", "तेज़"), ("blunt", "मंद"), ("heavy", "भारी"),
    ("light", "हल्का"), ("expensive", "महंगा"), ("cheap", "सस्ता"), ("easy", "आसान"), ("difficult", "कठिन"),
    ("left", "बायां"), ("right", "दायां"), ("first", "पहला"), ("last", "आखिरी"), ("inside", "अंदर"),
    ("outside", "बाहर"), ("early", "जल्दी"), ("late", "देर से"), ("near", "पास"), ("far", "दूर"),
    ("correct", "सही"), ("wrong", "गलत"), ("true", "सच"), ("false", "झूठ"), ("possible", "संभव"),
    ("impossible", "असंभव"), ("stronger", "अधिक मज़बूत"), ("weaker", "अधिक कमज़ोर"), ("bigger", "अधिक बड़ा"),
    ("smaller", "अधिक छोटा"), ("faster", "अधिक तेज़"), ("slower", "अधिक धीमा"), ("happier", "अधिक खुश"),
    ("sadder", "अधिक उदास"), ("richer", "अधिक अमीर"), ("poorer", "अधिक गरीब"), ("taller", "अधिक लंबा"),
    ("shorter", "अधिक छोटा"), ("warmer", "अधिक गर्म"), ("colder", "अधिक ठंडा"),
    ("running", "दौड़ना"), ("walking", "चलना"), ("jumping", "कूदना"), ("sitting", "बैठना"), ("standing", "खड़ा होना"),
    ("eating", "खाना"), ("drinking", "पीना"), ("reading", "पढ़ना"), ("writing", "लिखना"), ("speaking", "बोलना"),
    ("listening", "सुनना"), ("seeing", "देखना"), ("touching", "छूना"), ("thinking", "सोचना"), ("understanding", "समझना"),
    ("remembering", "याद करना"), ("forgetting", "भूलना"), ("helping", "मदद करना"), ("teaching", "सिखाना"),
    ("learning", "सीखना"), ("buying", "खरीदना"), ("selling", "बेचना"), ("opening", "खोलना"), ("closing", "बंद करना"),
    ("starting", "शुरू करना"), ("stopping", "रोकना"), ("winning", "जीतना"), ("losing", "हारना"), ("giving", "देना"),
    ("taking", "लेना"), ("showing", "दिखाना"), ("hiding", "छिपाना"), ("breaking", "तोड़ना"), ("fixing", "सुधारना"),
    ("creating", "बनाना"), ("destroying", "नष्ट करना"), ("loved", "प्यार किया"), ("hated", "नफरत किया"),
    ("liked", "पसंद किया"), ("disliked", "नापसंद किया"), ("won", "जीता"), ("lost", "हारा"), ("gave", "दिया"),
    ("took", "लिया"), ("showed", "दिखाया"), ("hid", "छिपाया"), ("broke", "तोड़ दिया"), ("fixed", "सुधारा"),
    ("created", "बनाया"), ("destroyed", "नष्ट किया"), ("happy", "प्रसन्न"), ("happily", "प्रसन्नतापूर्वक"),
    ("sad", "दुखी"), ("sadly", "दुखपूर्वक"), ("angry", "क्रोधित"), ("angrily", "क्रोधित रूप से"),
    ("brave", "साहसी"), ("bravely", "साहसपूर्वक"), ("quick", "शीघ्र"), ("quickly", "शीघ्रता से"),
    ("slow", "धीमा"), ("slowly", "धीरे-धीरे"), ("soft", "नरम"), ("softly", "नरमी से"),
    ("hard", "कठोर"), ("hardly", "मुश्किल से"), ("clean", "स्वच्छ"), ("cleanly", "स्वच्छता से"),
    ("dirty", "गंदा"), ("dirtier", "अधिक गंदा"), ("dirtiest", "सबसे गंदा"), ("brighter", "अधिक चमकदार"),
    ("brightest", "सबसे चमकदार"), ("darker", "अधिक अंधेरा"), ("darkest", "सबसे अंधेरा"),
    ("tree", "पेड़"), ("flower", "फूल"), ("leaf", "पत्ता"), ("river", "नदी"), ("mountain", "पहाड़"),
    ("ocean", "महासागर"), ("sky", "आकाश"), ("earth", "पृथ्वी"), ("sun", "सूरज"), ("moon", "चंद्रमा"),
    ("star", "तारा"), ("rain", "बारिश"), ("storm", "तूफान"), ("wind", "हवा"), ("snow", "बर्फ"),
    ("joy", "आनंद"), ("fear", "भय"), ("anger", "गुस्सा"), ("love", "प्यार"), ("hate", "नफरत"),
    ("surprise", "आश्चर्य"), ("excitement", "उत्साह"), ("anxiety", "चिंता"), ("pride", "गर्व"), ("shame", "शर्म"),
    ("computer", "कंप्यूटर"), ("internet", "इंटरनेट"), ("software", "सॉफ़्टवेयर"), ("hardware", "हार्डवेयर"),
    ("program", "प्रोग्राम"), ("database", "डेटाबेस"), ("algorithm", "अल्गोरिदम"), ("server", "सर्वर"),
    ("network", "नेटवर्क"), ("website", "वेबसाइट"),
    ("house", "घर"), ("car", "गाड़ी"), ("road", "सड़क"), ("market", "बाज़ार"), ("school", "स्कूल"),
    ("teacher", "शिक्षक"), ("doctor", "डॉक्टर"), ("police", "पुलिस"), ("restaurant", "रेस्टोरेंट"),
    ("kitchen", "रसोई"),("engineer", "अभियंता"), ("scientist", "वैज्ञानिक"), ("artist", "कलाकार"), ("actor", "अभिनेता"),
    ("singer", "गायक"), ("writer", "लेखक"), ("farmer", "किसान"), ("lawyer", "वकील"), ("judge", "न्यायाधीश"),
    ("athlete", "खिलाड़ी"),
    ("pen", "कलम"), ("book", "किताब"), ("table", "मेज़"), ("chair", "कुर्सी"), ("window", "खिड़की"),
    ("door", "दरवाज़ा"), ("bottle", "बोतल"), ("clock", "घड़ी"), ("lamp", "दीपक"), ("phone", "फ़ोन"),
    ("red", "लाल"), ("blue", "नीला"), ("green", "हरा"), ("yellow", "पीला"), ("black", "काला"),
    ("white", "सफ़ेद"), ("pink", "गुलाबी"), ("purple", "बैंगनी"), ("brown", "भूरा"), ("orange", "नारंगी"),
    ("morning", "सुबह"), ("afternoon", "दोपहर"), ("evening", "शाम"), ("night", "रात"), ("yesterday", "कल"),
    ("today", "आज"), ("tomorrow", "कल"), ("hour", "घंटा"), ("minute", "मिनट"), ("second", "सेकंड"),
    ("left", "बायां"), ("right", "दायां"), ("up", "ऊपर"), ("down", "नीचे"), ("forward", "आगे"),
    ("backward", "पीछे"), ("north", "उत्तर"), ("south", "दक्षिण"), ("east", "पूर्व"), ("west", "पश्चिम"),
    ("dog", "कुत्ता"), ("cat", "बिल्ली"), ("elephant", "हाथी"), ("tiger", "बाघ"), ("lion", "शेर"),
    ("horse", "घोड़ा"), ("monkey", "बंदर"), ("rabbit", "खरगोश"), ("deer", "हिरण"), ("bear", "भालू"),
    ("engineer", "अभियंता"), ("scientist", "वैज्ञानिक"), ("artist", "कलाकार"), ("actor", "अभिनेता"),
    ("singer", "गायक"), ("writer", "लेखक"), ("farmer", "किसान"), ("lawyer", "वकील"), ("judge", "न्यायाधीश"),
    ("athlete", "खिलाड़ी"), ("pilot", "पायलट"), ("chef", "रसोइया"), ("nurse", "नर्स"), ("soldier", "सैनिक"),
    ("bread", "रोटी"), ("rice", "चावल"), ("milk", "दूध"), ("butter", "मक्खन"), ("cheese", "पनीर"),
    ("sugar", "चीनी"), ("salt", "नमक"), ("pepper", "मिर्च"), ("fruit", "फल"), ("vegetable", "सब्ज़ी"),
    ("head", "सिर"), ("eye", "आंख"), ("ear", "कान"), ("nose", "नाक"), ("mouth", "मुंह"),
    ("hand", "हाथ"), ("leg", "टांग"), ("heart", "दिल"), ("brain", "मस्तिष्क"), ("skin", "त्वचा"),
    ("left", "बायां"), ("right", "दायां"), ("up", "ऊपर"), ("down", "नीचे"), ("forward", "आगे"),
    ("backward", "पीछे"), ("north", "उत्तर"), ("south", "दक्षिण"), ("east", "पूर्व"), ("west", "पश्चिम"),
    ("government", "सरकार"), ("vote", "वोट"), ("tax", "कर"), ("investment", "निवेश"), ("loan", "ऋण"),
    ("physics", "भौतिकी"), ("chemistry", "रसायन"), ("biology", "जीवविज्ञान"), ("medicine", "चिकित्सा"),
    ("university", "विश्वविद्यालय"), ("astronaut", "अंतरिक्ष यात्री"), ("galaxy", "आकाशगंगा"),
    ("meteor", "उल्का"), ("oxygen", "ऑक्सीजन"), ("hydrogen", "हाइड्रोजन"),
    ("athlete", "खिलाड़ी"), ("stadium", "स्टेडियम"), ("referee", "रेफरी"), ("goal", "गोल"), ("tournament", "प्रतियोगिता"),
    ("inflation", "मुद्रास्फीति"), ("recession", "मंदी"), ("subsidy", "सब्सिडी"), ("taxation", "कराधान"), ("capitalism", "पूंजीवाद"),
    ("highway", "राजमार्ग"), ("junction", "चौराहा"), ("navigation", "नेविगेशन"), ("commute", "आवागमन"), ("freight", "मालवाहक"),
    ("humidity", "आर्द्रता"), ("forecast", "पूर्वानुमान"), ("monsoon", "मॉनसून"), ("hailstorm", "ओलावृष्टि"), ("cyclone", "चक्रवात"),
    ("democracy", "लोकतंत्र"), ("parliament", "संसद"), ("constitution", "संविधान"), ("governance", "शासन"), ("diplomacy", "कूटनीति"),
    ("experiment", "प्रयोग"), ("hypothesis", "परिकल्पना"), ("quantum", "क्वांटम"), ("genetics", "आनुवंशिकी"), ("evolution", "विकास"),
    ("diagnosis", "निदान"), ("vaccine", "टीका"), ("therapy", "चिकित्सा"), ("surgeon", "शल्य चिकित्सक"), ("pharmacy", "फार्मेसी"),
    ("curriculum", "पाठ्यक्रम"), ("scholarship", "छात्रवृत्ति"), ("discipline", "अनुशासन"), ("examination", "परीक्षा"), ("literacy", "साक्षरता"),
    ("satellite", "उपग्रह"), ("nebula", "निहारिका"), ("black hole", "ब्लैक होल"), ("orbit", "कक्षा"), ("cosmology", "ब्रह्माण्ड विज्ञान"),
    ("civilization", "सभ्यता"), ("archaeology", "पुरातत्व"), ("revolution", "क्रांति"), ("manuscript", "पांडुलिपि"), ("dynasty", "राजवंश"),
    ("legislation", "विधान"), ("jurisdiction", "अधिकार क्षेत्र"), ("plaintiff", "वादी"), ("verdict", "फैसला"), ("appeal", "अपील"),
    ("sculpture", "मूर्तिकला"), ("canvas", "कैनवास"), ("portrait", "चित्र"), ("mosaic", "मोज़ेक"), ("calligraphy", "सुलेख"),
    ("melody", "संगीत"), ("orchestra", "वाद्यवृंद"), ("chorus", "कोरस"), ("composer", "संगीतकार"), ("symphony", "सिंफनी"),
    ("existence", "अस्तित्व"), ("metaphysics", "अधिभौतिकी"), ("ethics", "नीतिशास्त्र"), ("logic", "तर्कशास्त्र"), ("aesthetics", "सौंदर्यशास्त्र"),
    ("novel", "उपन्यास"), ("poetry", "काव्य"), ("manuscript", "पांडुलिपि"), ("epic", "महाकाव्य"), ("prose", "गद्य")
]

# %%
with open('cross_alignment_data/sample.txt', encoding='utf-8') as f:
    content = f.readlines()

content = [x.strip().split(' ') for x in content]
content = [(x[0], x[1]) for x in content]

# %%
content = [
    ("mediate", "मध्यस्थता"),
    ("meditate", "ध्यान"),
    ("melt", "पिघलना"),
    ("mend", "मरम्मत"),
    ("mention", "उल्लेख"),
    ("merge", "विलय"),
    ("merit", "योग्यता"),
    ("migrate", "प्रवास"),
    ("minimize", "न्यूनतम"),
    ("minimize", "न्यूनतम"), 
    ("mislead", "गुमराह"),
    ("misplace", "गलत जगह रखना"),
    ("miss", "याद करना"),
    ("mistake", "गलती"),
    ("mitigate", "कम करना"),
    ("mobilize", "गतिशील"),
    ("mock", "मजाक उड़ाना"),
    ("modify", "संशोधित"),
    ("monitor", "निगरानी"),
    ("motivate", "प्रेरित"),
    ("mourn", "शोक मनाना"),
    ("move", "चाल"),
    ("mow", "घास काटना"),
    ("muddle", "उलझन"),
    ("multiply", "गुणा"),
    ("murder", "हत्या"),
    ("murmur", "बड़बड़ाना"),
    ("muster", "इकट्ठा करना"),
    ("mute", "मूक"),
    ("mutter", "बड़बड़ाना"),
    ("nail", "कील"),
    ("name", "नाम"),
    ("narrate", "वर्णन करना"),
    ("narrow", "संकीर्ण"),
    ("navigate", "पथ प्रदर्शन"),
    ("negotiate", "बातचीत करना"),
    ("neglect", "उपेक्षा"),
    ("negotiate", "बातचीत करना"),
    ("nominate", "नामزد करना"),
    ("normalize", "सामान्यीकरण"),
    ("notify", "सूचित करना"),
    ("nourish", "पोषण"),
    ("obey", "पालन करना"),
    ("object", "विरोध करना"),
    ("observe", "देखना"),
    ("obstruct", "बाधा डालना"),
    ("obtain", "प्राप्त करना"),
    ("occupy", "कब्जा करना"),
    ("occur", "होना"),
    ("offer", "प्रस्ताव"),
    ("offend", "अपमानित करना"),
    ("offset", "पूरा करना"),
    ("omit", "छोड़ना"),
    ("oppose", "विरोध करना"),
    ("oppress", "दमन करना"),
    ("opt", "चुनना"),
    ("optimize", "इष्टतम बनाना"),
    ("order", "आदेश देना"),
    ("organize", "व्यवस्थित करना"),
    ("originate", "उद्भव"),
    ("ornament", "सजाना"),
    ("oscillate", "दोलायमान"),
    ("overcome", "जीतना"),
    ("overlook", "अनदेखा करना"),
    ("overpower", "काबू पाना"),
    ("overthrow", "उखाड़ फेंकना"),
    ("overwhelm", "अभिभूत करना"),
    ("owe", "ऋणी होना"),
    ("own", "स्वयं का"),
    ("pacify", "शांत करना"),
    ("pack", "पैक करना"),
    ("paint", "पेंट करना"),
    ("panic", "घबराना"),
    ("parade", "परेड"),
    ("paradox", "विरोधाभास"),
    ("pardon", "माफ करना"),
    ("partake", "भाग लेना"),
    ("participate", "भाग लेना"),
    ("particularize", "विशेष रूप से बताना"),
    ("partition", "विभाजन"),
    ("partner", "साझेदार"),
    ("pass", "पास करना"),
    ("paste", "चिपकाना"),
    ("pause", "रुकना"),
    ("pave", "पक्का करना"),
    ("paw", "पंजा मारना"),
    ("pay", "भुगतान करना"),
    ("peck", "चोंच मारना"),
    ("peel", "छीलना"),
    ("penetrate", "प्रवेश करना"),
    ("perceive", "अनुभव करना"),
    ("perch", "बैठना"),
    ("perform", "प्रदर्शन करना"),
    ("permit", "अनुमति देना"),
    ("perpetuate", "स्थायी बनाना"),
    ("persuade", "मनाना"),
    ("perturb", "परेशान करना"),
    ("pervade", "व्याप्त करना"),
    ("phase", "चरण"),
    ("phenomenon", "घटना"),
    ("philosophize", "दार्शनिक चर्चा करना"),
    ("photograph", "फोटो खींचना"),
    ("phrase", "वाक्यांश"),
    ("pine", "तड़पना"),
    ("pioneer", "अग्रणी"),
    ("piss", "पेशाब करना"),
    ("pitch", "फेंकना"),
    ("pity", "दया"),
    ("plan", "योजना बनाना"),
    ("plant", "रोपना"),
    ("play", "खेलना"),
    ("plead", "दलील देना"),
    ("please", "खुश करना"),
    ("pledge", "प्रतिज्ञा"),
    ("plot", "साजिश रचना"),
    ("plunge", "डुबकी लगाना"),
    ("ponder", "विचार करना"),
    ("pool", "एकत्रित करना"),
    ("possess", "कब्जा करना"),
    ("postpone", "स्थगित करना"),
    ("pour", "डालना"),
    ("practice", "अभ्यास करना"),
    ("praise", "प्रशंसा करना"),
    ("pray", "प्रार्थना करना"),
    ("preach", "उपदेश देना"),
    ("precede", "पूर्ववर्ती होना"),
    ("precipitate", "कारण बनना"),
    ("predict", "भविष्यवाणी करना"),
    ("predominate", "प्रभुत्वशाली होना"),
    ("prefer", "पसंद करना"),
    ("prejudice", "पूर्वाग्रह"),
    ("preliminary", "प्रारंभिक"),
    ("prepare", "तैयारी करना"),
    ("prescribe", "निर्धारित करना"),
    ("present", "पेश करना"),
    ("preserve", "संरक्षित करना"),
    ("preside", "अध्यक्षता करना"),
    ("press", "दबाना"),
    ("presume", "मानना"),
    ("prevail", "जीतना"),
    ("prevent", "रोकना"),
    ("prey", "शिकार"),
    ("price", "कीमत"),
    ("prick", "छेदना"),
    ("pride", "गर्व"),
    ("print", "छापना"),
    ("prioritize", "प्राथमिकता देना"),
    ("probe", "जांचना"),
    ("proceed", "आगे बढ़ना"),
    ("process", "प्रक्रिया"),
    ("proclaim", "घोषणा करना"),
    ("procure", "प्राप्त करना"),
    ("produce", "उत्पादन करना"),
    ("profess", "घोषणा करना"),
    ("profile", "प्रोफ़ाइल"),
    ("profit", "लाभ"),
    ("prohibit", "निषेध"),
    ("project", "प्रोजेक्ट"),
    ("prolong", "लम्बा करना"),
    ("promote", "पदोन्नति"),
    ("prompt", "प्रेरित करना"),
    ("pronounce", "उच्चारण करना"),
    ("proof", "सबूत"),
    ("propagate", "प्रचार करना"),
    ("propel", "धकेलना"),
    ("prophesize", "भविष्यवाणी करना"),
    ("propose", "प्रस्तावित करना"),
    ("prosecute", "मुकदमा चलाना"),
    ("prosper", "सफल होना"),
    ("protect", "रक्षा करना"),
    ("protest", "विरोध करना"),
    ("provoke", "उकसाना"),
    ("prune", "छांटना"),
    ("publish", "प्रकाशित करना"),
    ("pull", "खींचना"),
    ("pulse", "नाड़ी"),
    ("punish", "सजा देना"),
    ("purchase", "खरीदना"),
    ("pursue", "पीछा करना"),
    ("push", "धक्का देना"),
    ("puzzle", "पहेली")]

# %%
word_pairs.extend(content)

# %%
len(word_pairs)
# Out:
# 4872

# %%
len(set(word_pairs))
# Out:
# 2487

# %%
word_pairs = list(set(word_pairs))

# %%
import pickle 
pickle.dump(word_pairs, open('cross_alignment_data/word_pairs.pkl', 'wb'))

# %%
word_pairs
# Out:
# [('hardly', 'मुश्किल से'),
#  ('opening', 'खोलना'),
#  ('afternoon', 'दोपहर'),
#  ('day', 'दिन'),
#  ('surprise', 'आश्चर्य'),
#  ('running', 'दौड़ना'),
#  ('industries', 'उद्योग'),
#  ('air', 'वायु'),
#  ('bank', 'बैंक'),
#  ('bottle', 'बोतल'),
#  ('salary', 'वेतन'),
#  ('story', 'कहानी'),
#  ('showing', 'दिखाना'),
#  ('walking', 'चलना'),
#  ('darker', 'अधिक अंधेरा'),
#  ('strong', 'मजबूत'),
#  ('quick', 'शीघ्र'),
#  ('leader', 'नेता'),
#  ('shorter', 'अधिक छोटा'),
#  ('writer', 'लेखक'),
#  ('angrily', 'क्रोधित रूप से'),
#  ('jump', 'कूदना'),
#  ('interesting', 'दिलचस्प'),
#  ('defeat', 'पराजय'),
#  ('sit', 'बैठना'),
#  ('question', 'प्रश्न'),
#  ('small', 'छोटा'),
#  ('moon', 'चंद्रमा'),
#  ('closed', 'बंद'),
#  ('network', 'नेटवर्क'),
#  ('doubt', 'संदेह'),
#  ('daughter', 'बेटी'),
#  ('pen', 'पेन'),
#  ('employers', 'नियोक्ता'),
#  ('unemployment', 'बेरोजगारी'),
#  ('trust', 'विश्वास'),
#  ('giving', 'देना'),
#  ('success', 'सफलता'),
#  ('forward', 'आगे'),
# ...
